# %%
import os, re, sys, json, pandas
from Haversine.haversine import Waypoints
waypoints = Waypoints()
waypoints.username = 'eddo888'
waypoints.passwords = '...'

# %%
wp = pandas.read_json(json.dumps(waypoints.list())) #.set_index('id')
wp
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'haversine.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
#         id             description   latitude   longitude  elevation
# 0     0MTB                Mt Blanc  45.832119    6.865575        0.0
# 1     0A51                 Area 51  37.233333 -115.808333        0.0
# 2     0PYR  Pyramids of Giza Egypt  29.975273   31.135379        0.0
# 3     0FRA                    Home -33.911110  151.159164        0.0
# 4     0LND               London UK  51.528558   -0.241678        0.0
# ..     ...                     ...        ...         ...        ...
# 192  0YDKL       Docklands Helipad -37.819444  144.936389       76.0
# 193   YIER      Pier 35 Helicoport -37.823056  144.908056       47.0
# ...
